# %% [markdown]
# # name Mukhammadsaiid Norbaev
# # last update 09/02/2026
# # lab3

# %%
graph = {
 '5' : ['3','7'],
 '3' : ['2', '4'],
 '7' : ['8'],
 '2' : [],
 '4' : ['8'],
 '8' : []
}

graph
# Out:
# {'5': ['3', '7'], '3': ['2', '4'], '7': ['8'], '2': [], '4': ['8'], '8': []}
